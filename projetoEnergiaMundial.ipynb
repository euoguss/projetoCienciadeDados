# %% [markdown]
# # 📈 Previsão de Consumo de Energia Mundial por Fonte (50 anos)
#
# Este notebook apresenta a previsão de consumo de energia separada por tipo (Fóssil, Renovável e Nuclear), utilizando regressão linear.
#
# A base de dados contém o consumo de diversas fontes de energia entre os anos de 1983 e 2014. O objetivo é prever a tendência até 2064.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv("data/substituicaoConsumoDeEnergiaMundial.csv")

df["Energia_Fossil"] = df["Coal"] + df["Oil"] + df["Gas"]
df["Energia_Renovavel"] = (
    df["Hydropower"]
    + df["Wind"]
    + df["Solar"]
    + df["Biofuels"]
    + df["Other_renewables"]
    + df["Traditional_biomass"]
)
df["Energia_Nuclear"] = df["Nuclear"]

# %%
X = df[["Year"]]
y_fossil = df["Energia_Fossil"]
y_renovavel = df["Energia_Renovavel"]
y_nuclear = df["Energia_Nuclear"]

# Treinar modelos
model_fossil = LinearRegression().fit(X, y_fossil)
model_renovavel = LinearRegression().fit(X, y_renovavel)
model_nuclear = LinearRegression().fit(X, y_nuclear)

# %%
anos_futuros = pd.DataFrame({"Year": list(range(df["Year"].min(), 2073))})
fossil_pred = model_fossil.predict(anos_futuros)
renovavel_pred = model_renovavel.predict(anos_futuros)
nuclear_pred = model_nuclear.predict(anos_futuros)

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Year"], y_fossil, label="Fóssil - Real", marker='o')
plt.plot(anos_futuros["Year"], fossil_pred, label="Fóssil - Previsto", linestyle='--')
plt.title("Consumo de Energia Fóssil - Histórico e Previsão (50 anos)")
plt.xlabel("Ano")
plt.ylabel("Consumo de Energia")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Year"], y_renovavel, label="Renovável - Real", marker='o')
plt.plot(anos_futuros["Year"], renovavel_pred, label="Renovável - Previsto", linestyle='--')
plt.title("Consumo de Energia Renovável - Histórico e Previsão (50 anos)")
plt.xlabel("Ano")
plt.ylabel("Consumo de Energia")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df["Year"], y_nuclear, label="Nuclear - Real", marker='o')
plt.plot(anos_futuros["Year"], nuclear_pred, label="Nuclear - Previsto", linestyle='--')
plt.title("Consumo de Energia Nuclear - Histórico e Previsão (50 anos)")
plt.xlabel("Ano")
plt.ylabel("Consumo de Energia")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

plt.plot(df["Year"], y_fossil, label="Fóssil - Real", marker='o')
plt.plot(anos_futuros["Year"], fossil_pred, label="Fóssil - Previsto", linestyle='--')

plt.plot(df["Year"], y_renovavel, label="Renovável - Real", marker='o')
plt.plot(anos_futuros["Year"], renovavel_pred, label="Renovável - Previsto", linestyle='--')

plt.plot(df["Year"], y_nuclear, label="Nuclear - Real", marker='o')
plt.plot(anos_futuros["Year"], nuclear_pred, label="Nuclear - Previsto", linestyle='--')

plt.title("Previsão de Consumo de Energia por Tipo - 50 anos")
plt.xlabel("Ano")
plt.ylabel("Consumo de Energia (unidade do dataset)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
anos_futuros = pd.DataFrame({"Year": list(range(df["Year"].min(), 2123))})
fossil_pred = model_fossil.predict(anos_futuros)
renovavel_pred = model_renovavel.predict(anos_futuros)
nuclear_pred = model_nuclear.predict(anos_futuros)

# %%
plt.figure(figsize=(12, 6))

plt.plot(df["Year"], y_fossil, label="Fóssil - Real", marker='o')
plt.plot(anos_futuros["Year"], fossil_pred, label="Fóssil - Previsto", linestyle='--')

plt.plot(df["Year"], y_renovavel, label="Renovável - Real", marker='o')
plt.plot(anos_futuros["Year"], renovavel_pred, label="Renovável - Previsto", linestyle='--')

plt.plot(df["Year"], y_nuclear, label="Nuclear - Real", marker='o')
plt.plot(anos_futuros["Year"], nuclear_pred, label="Nuclear - Previsto", linestyle='--')

plt.title("Previsão de Consumo de Energia por Tipo - 50 anos")
plt.xlabel("Ano")
plt.ylabel("Consumo de Energia (unidade do dataset)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Interpretação dos Gráficos
#
# Este gráfico mostra a **evolução e a projeção do consumo de energia mundial** ao longo do tempo, separando por três grandes grupos:
#
# - **Fóssil**: Soma do consumo de carvão (`Coal`), petróleo (`Oil`) e gás natural (`Gas`).
# - **Renovável**: Inclui hidroelétrica, solar, eólica, biocombustíveis, biomassa tradicional e outras renováveis.
# - **Nuclear**: Representa o consumo de energia proveniente de fontes nucleares.
#
# ### 🔹 Linhas reais (com pontos)
# Essas linhas mostram os dados reais extraídos do dataset original, com base em registros históricos.
#
# ### 🔸 Linhas tracejadas
# São as previsões geradas por um modelo de **regressão linear simples**, indicando a tendência para os próximos 50 anos com base nos dados históricos.
#
# ---
#
# ### 📈 Tendências observadas:
# - A energia **fóssil** mostra uma leve tendência de estabilização, com possível queda futura.
# - A **renovável** cresce de forma consistente, indicando uma **transição energética** em andamento.
# - A **nuclear** cresce de forma mais lenta, mas contínua.
#
# Essa análise pode ajudar a entender o ritmo da transição energética global e apoiar políticas de incentivo às fontes limpas.

# %% [markdown]
# ## --- Fim do primeiro notebook ---

# %% [markdown]
# # Dicionário de Dados: Consumo Mundial de Energia
#
# ## Descrição
# Este conjunto de dados apresenta o consumo mundial de energia por diferentes fontes, com dados anuais de 1983 a 2022.
#
# ## Variáveis
#
# | Coluna | Tipo | Descrição |
# |--------|------|-----------|
# | Year | Integer | Ano de referência dos dados |
# | Other_renewables | Float | Consumo de energia de outras fontes renováveis (TWh) |
# | Biofuels | Float | Consumo de energia proveniente de biocombustíveis (TWh) |
# | Solar | Float | Consumo de energia solar (TWh) |
# | Wind | Float | Consumo de energia eólica (TWh) |
# | Hydropower | Float | Consumo de energia hidrelétrica (TWh) |
# | Nuclear | Float | Consumo de energia nuclear (TWh) |
# | Gas | Float | Consumo de energia proveniente de gás natural (TWh) |
# | Oil | Float | Consumo de energia proveniente de petróleo (TWh) |
# | Coal | Float | Consumo de energia proveniente de carvão (TWh) |
# | Traditional_biomass | Float | Consumo de energia proveniente de biomassa tradicional (TWh) |
#
# ## Observações:
# - Unidade de medida: Terawatt-hora (TWh)
# - Período: 40 anos (1983-2022)
# - Frequência: Anual
# - Os dados apresentam valores decimais com até 6 casas de precisão
# - O conjunto de dados não apresenta valores nulos
#
# ## Fonte dos Dados
# Este arquivo está localizado em: 1-substituicaoConsumoDeEnergiaMundial.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/substituicaoConsumoDeEnergiaMundial.csv")
df
# Out:
#     Year  Other_renewables     Biofuels        Solar         Wind  Hydropower  \
# 0   1983         211.77058    49.019240     0.008871     0.096974   5552.5425
# 1   1984         236.32065    57.806423     0.018662     0.132342   5740.6200
# 2   1985         243.15495    68.410090     0.034737     0.189898   5852.6050
# 3   1986         263.68542    84.202990     0.044898     0.410523   5931.9126
# 4   1987         282.44330    85.330120     0.031353     0.577727   6012.1157
# 5   1988         290.86093    89.560196     0.030149     0.980478   6204.8037
# 6   1989         322.35043    95.689240     0.775391     7.835361   6172.9750
# 7   1990         361.19138   106.642880     1.148346    10.741176   6383.7080
# 8   1991         376.81265   110.728714     1.494234    12.082573   6531.1080
# 9   1992         404.78116   108.796330     1.379965    13.994874   6530.3900
# 10  1993         418.23853   114.444310     1.646089    16.867165   6923.6710
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Oil"], label="Oil energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Oil Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Petróleo (1983-2022)
#
# O gráfico mostra o consumo global de petróleo em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento geral com algumas flutuações, incluindo uma queda notável em 2020, provavelmente devido à pandemia de COVID-19, seguida por uma recuperação parcial. O crescimento é mais acentuado a partir de meados dos anos 2000.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Gas"], label="Gas energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Gas Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Gás (1983-2022)
#
# O gráfico mostra o consumo global de gás em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento constante ao longo do período, com aceleração notável a partir de meados dos anos 2000. Uma pequena desaceleração é visível nos anos mais recentes, sugerindo possíveis mudanças no consumo ou na demanda.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Coal"], label="Coal energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Coal Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Carvão (1983-2022)
#
# O gráfico mostra o consumo global de carvão em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento geral com três fases distintas: um leve aumento inicial, seguido por um crescimento acelerado no início dos anos 2000, e uma estabilização com flutuações a partir de 2010.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Biofuels"], label="Biofuels energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Biofuels Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Biocombustíveis (1983-2022)
#
# O gráfico mostra o consumo global de biocombustíveis em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento geral, com um crescimento notavelmente rápido a partir de meados dos anos 2000. Isso sugere um aumento significativo na adoção de biocombustíveis como fonte de energia nas últimas duas décadas.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Hydropower"], label="Hydropower energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Hydropower Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Hidroeletricidade (1983-2022)
#
# O gráfico mostra o consumo global de hidroeletricidade em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento consistente ao longo do tempo, indicando um crescimento constante na utilização da energia hidrelétrica. O aumento parece ser bastante linear, sem grandes flutuações, sugerindo um desenvolvimento estável e progressivo do setor.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Nuclear"], label="Nuclear energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Nuclear Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Energia Nuclear (1983-2022)
#
# O gráfico mostra o consumo global de energia nuclear em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento geral até meados dos anos 2000, seguido por uma leve queda e subsequente estabilização. Houve uma desaceleração no crescimento do consumo nuclear na última década.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Solar"], label="Solar energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Solar Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Energia Solar (1983-2022)
#
# O gráfico mostra o consumo global de energia solar em Terawatts-hora (TWh) de 1983 a 2022. O consumo permaneceu praticamente nulo até meados dos anos 2000, seguido por um crescimento exponencial a partir de 2010. Este aumento dramático indica um rápido avanço e adoção da energia solar como fonte de energia nas últimas décadas.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Traditional_biomass"], label="Traditional Biomass energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Traditional Biomass Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Biomassa Tradicional (1983-2022)
#
# O gráfico mostra o consumo de biomassa tradicional em Terawatts-hora (TWh) de 1983 a 2022. Observa-se um aumento acentuado até o início dos anos 2000, seguido por um declínio gradual e estabilização a partir de 2015. Isso sugere uma mudança no uso de biomassa tradicional, possivelmente devido à adoção de outras fontes de energia ou mudanças nas práticas de consumo.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Wind"], label="Wind energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Wind Consumption")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo de Energia Eólica (1983-2022)
#
# O gráfico mostra o consumo global de energia eólica em Terawatts-hora (TWh) de 1983 a 2022. O consumo é praticamente nulo até o final dos anos 1990, com um aumento gradual no início dos anos 2000 e um crescimento exponencial a partir de 2010. Este aumento significativo indica um rápido desenvolvimento e adoção da energia eólica como fonte de energia nas últimas décadas.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["Year"], df["Biofuels"], label="Biofuels energy")
plt.plot(df["Year"], df["Solar"], label="Solar energy")
plt.plot(df["Year"], df["Wind"], label="Wind energy")
plt.plot(df["Year"], df["Hydropower"], label="Hidropower energy")
plt.plot(df["Year"], df["Nuclear"], label="Nuclear energy")
plt.plot(df["Year"], df["Gas"], label="Gas energy")
plt.plot(df["Year"], df["Oil"], label="Oil energy")
plt.plot(df["Year"], df["Coal"], label="Coal energy")
plt.plot(df["Year"], df["Traditional_biomass"], label="Traditional biomass energy")
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("World energy consumption by source")
plt.legend()
plt.show()

# %% [markdown]
# ## Análise Rápida: Consumo Global de Energia por Fonte (1983-2022)
#
# O gráfico compara o consumo global de diversas fontes de energia em Terawatts-hora (TWh) ao longo de quase quatro décadas. Observa-se:
#
# * **Domínio dos Combustíveis Fósseis**: Petróleo e gás natural mantêm-se como as maiores fontes de energia, com carvão em um distante terceiro lugar.
# * **Crescimento das Renováveis**: Solar e eólica apresentam um crescimento exponencial a partir de meados dos anos 2000, embora ainda representem uma fração menor do consumo total.
# * **Biomassa Tradicional Decrescente**: O consumo de biomassa tradicional diminui ao longo do tempo, indicando mudanças nos padrões de uso de energia.
# * **Estabilidade Nuclear e Hidrelétrica**: A energia nuclear e hidrelétrica mostram um crescimento constante, embora moderado, ao longo do período.
#
# Em resumo, o gráfico destaca a transição energética em curso, com um aumento notável nas energias renováveis, mas ainda sob o domínio dos combustíveis fósseis.

# %%
df['Fossil Fuels'] = df['Oil'] + df['Gas'] + df['Coal']

plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['Fossil Fuels'])
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Fossil Fuels Energy Consumption")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_213497/1331971537.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df['Renewables'] = df['Biofuels'] + df['Solar'] + df['Wind'] + df['Hydropower']

plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['Renewables'])
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Energy Renewables Consumption")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_213497/2688168825.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['Nuclear'],)
plt.xlabel("Year")
plt.ylabel("Consumption (TWh)")
plt.title("Nuclear Energy Consumption")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_213497/2909836864.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
